# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.DataFrame({"colours": ["Red", "Yellow", "Yellow", "Orange"]});
print(df.shape);

le = LabelEncoder();

df['colours'] = le.fit_transform(df[['colours']]);

df
# Out:
# (4, 1)
# /Users/dhananjaypuri/study/data-science/books-project/mcp-tut/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:120: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#    colours
# 0        1
# 1        2
# 2        2
# 3        0
