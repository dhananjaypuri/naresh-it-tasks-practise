# %%
import pandas as pd

# %%
df = pd.DataFrame({"Age": [20,22,'33', 24]});

print(df.dtypes);

df['Age'] = df['Age'].astype(int)

print(df['Age'].dtypes);
# Out:
# Age    object
# dtype: object
# int64
