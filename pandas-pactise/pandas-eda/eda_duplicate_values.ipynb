# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("pandas_duplicate_dataset.xlsx");
df
# Out:
#       Name Education  Marks       City
# 0     Siva    B.Tech     90  Hyderabad
# 1     Rama       MBA     45    Chennai
# 2  Krishna    B.Tech     95  Bangalore
# 3    Pavan       BBA     88     Mumbai
# 4     Siva    B.Tech     90  Hyderabad
# 5     Rama       MBA     45    Chennai
# 6    Bobby    B.Tech    100    Kolkata
# 7   Chinny       BBA     67     Jaipur
# 8  Krishna    B.Tech     95  Bangalore
# 9      Srk    B.Tech     49  Ahmedabad

# %%
## Print if data has duplicates
print(df.duplicated());
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# 8     True
# 9    False
# dtype: bool

# %%
# Print count of duplicate records
print(df.duplicated().sum());
# Out:
# 3

# %%
# Display the rows which are duplicates
print(df[df.duplicated()]);
# Out:
#       Name Education  Marks       City
# 4     Siva    B.Tech     90  Hyderabad
# 5     Rama       MBA     45    Chennai
# 8  Krishna    B.Tech     95  Bangalore
