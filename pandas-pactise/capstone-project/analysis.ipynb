# %%
import pandas as pd
import numpy as np

# %%
## Data ingestion
df = pd.read_csv("LoanData.csv");
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
## print shape
print(df.shape);
# Out:
# (614, 13)

# %%
## print list of column names and number of columns and rows
print("Columsn names\n", df.columns.to_list())
print("Num of Rows", df.shape[0]);
print("Num of Columns", df.shape[1]);
# Out:
# Columsn names
#  ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status']
# Num of Rows 614
# Num of Columns 13

# %%
#Q1 Display first 10 records of the dataset.
print(df.head(10));
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
#Q2 Find: Number of rows Number of columns
print("Num of Rows", df.shape[0]);
print("Num of Columns", df.shape[1]);
# Out:
# Num of Rows 614
# Num of Columns 13

# %%
# Q3 Display data types of all columns.

print(df.dtypes)
# Out:
# Loan_ID                  str
# Gender                   str
# Married                  str
# Dependents               str
# Education                str
# Self_Employed            str
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area            str
# Loan_Status              str
# dtype: object

# %%
#Q4 Find total missing values in each column.

print(df.isna().sum(axis=0));
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#Q5 Find total duplicate records in the dataset.

print("Number of Duplicated rows", len(df[df.duplicated()]));
# Out:
# Number of Duplicated rows 0

# %%
# Q6 Find unique values present in: Gender Education Property_Area

print("Gender : ", df['Gender'].unique());
print("Education : ", df['Education'].unique());
print("Property_Area : ", df['Property_Area'].unique());
# Out:
# Gender :  <StringArray>
# ['Male', 'Female', nan]
# Length: 3, dtype: str
# Education :  <StringArray>
# ['Graduate', 'Not Graduate']
# Length: 2, dtype: str
# Property_Area :  <StringArray>
# ['Urban', 'Rural', 'Semiurban']
# Length: 3, dtype: str

# %%
# Q7 Find frequency count of Gender.
print(df['Gender'].value_counts())
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
# Q8 Find frequency count of Education.
print(df['Education'].value_counts())
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
# Q9 Find frequency count of Loan_Status.
print(df['Loan_Status'].value_counts())
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
# Q10 Calculate loan approval percentage.

total = df.shape[0]

approval_percentage = df['Loan_Status'].value_counts().loc['Y']/total*100;
print(approval_percentage);
# Out:
# 68.72964169381108

# %%
# Q11 Find count of applicants based on Property_Area.
print(df['Property_Area'].value_counts());
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
# Q12 Find how many applicants are:Married Unmarried

print(df['Married'].value_counts());
# Out:
# Married
# Yes    398
# No     213
# Name: count, dtype: int64

# %%
# Q13 Find: Mean Median Mode of ApplicantIncome.

print("Mean : ", df['ApplicantIncome'].mean());
print("Median : ", df['ApplicantIncome'].median());
print("Mode : ", df['ApplicantIncome'].mode());
# Out:
# Mean :  5403.459283387622
# Median :  3812.5
# Mode :  0    2500
# Name: ApplicantIncome, dtype: int64

# %%
# Q14 Find: Minimum LoanAmount Maximum LoanAmount
print("Maximum Amount", df['LoanAmount'].max());
print("Minimum Amount" , df['LoanAmount'].min());
# Out:
# Maximum Amount 700.0
# Minimum Amount 9.0

# %%
# Q15 Find summary statistics for all numerical columns.
columns = df.columns.to_list();

# for col in columns:
#     if df.dtypes.loc[col] in [str, float , int]:
#         print(f"Stats for Column: {col}");
#         print("Mean", df[col].mean());
#         print("Median", df[col].median());
#         print("Max", df[col].max());
#         print("Min", df[col].min());
#         print("Mode", df[col].mode());
#         print("Unique", df[col].unique());
#         print("Count", df[col].count());

## OR

print(df.describe());
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
# Q16 Find top 10 applicants with highest ApplicantIncome.

print(df.loc[df['ApplicantIncome'].sort_values(ascending=False).head(10).index.to_list(), ['Loan_ID', 'ApplicantIncome']]);
# Out:
#       Loan_ID  ApplicantIncome
# 409  LP002317            81000
# 333  LP002101            63337
# 171  LP001585            51763
# 155  LP001536            39999
# 185  LP001640            39147
# 443  LP002422            37719
# 183  LP001637            33846
# 126  LP001448            23803
# 506  LP002624            20833
# 284  LP001922            20667

# %%
# Q17 Find average LoanAmount.

print(df['LoanAmount'].mean());
# Out:
# 146.41216216216216

# %%
# Q18 Find average CoapplicantIncome.
print(df['CoapplicantIncome'].mean());
# Out:
# 1621.2457980271008

# %%
# Q19 Find average ApplicantIncome based on Education.

print(df.groupby('Education')['ApplicantIncome'].mean());
# Out:
# Education
# Graduate        5857.433333
# Not Graduate    3777.283582
# Name: ApplicantIncome, dtype: float64

# %%
# Q20 Find average LoanAmount based on Gender.

print(df.groupby('Gender')['LoanAmount'].mean());
# Out:
# Gender
# Female    126.697248
# Male      149.265957
# Name: LoanAmount, dtype: float64

# %%
# Q21 Find average LoanAmount based on Property_Area.

print(df.groupby('Property_Area')['LoanAmount'].mean());
# Out:
# Property_Area
# Rural        152.260116
# Semiurban    145.504386
# Urban        142.198953
# Name: LoanAmount, dtype: float64

# %%
# Q22 Find average ApplicantIncome for: Married and Unmarried

print(df.groupby('Married')['ApplicantIncome'].mean());
# Out:
# Married
# No     4970.384977
# Yes    5629.173367
# Name: ApplicantIncome, dtype: float64

# %%
# Q23 Find average LoanAmount grouped by Loan_Status.

print(df.groupby('Loan_Status')['LoanAmount'].mean());
# Out:
# Loan_Status
# N    151.220994
# Y    144.294404
# Name: LoanAmount, dtype: float64

# %%
# Q24 Find average ApplicantIncome grouped by Credit_History.

print(df.groupby('Credit_History')['ApplicantIncome'].mean());
# Out:
# Credit_History
# 0.0    5679.438202
# 1.0    5426.526316
# Name: ApplicantIncome, dtype: float64

# %%
# Q25 Find count of applicants grouped by Dependents.

print(df.groupby('Dependents')['Loan_ID'].count());
# Q25 Find count of applicants grouped by Dependents.

print(df.groupby('Dependents').size());
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Loan_ID, dtype: int64
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# dtype: int64

# %%
# # Q26 Find loan approval rate by Gender.
# # print(len(df.loc[df['Loan_Status'].isin(['Y'])])/len(df)*100);

# approved_male_loan = len(df.loc[(df['Gender']=='Male')&(df['Loan_Status']=='Y')]);
# approved_female_loan = len(df.loc[(df['Gender']=='Female')&(df['Loan_Status']=='Y')])

# total_males = len(df.loc[df['Gender']=='Male']);
# total_females = len(df.loc[df['Gender']=='Female']);

# rate_males = approved_male_loan/total_males*100;
# rate_females = approved_female_loan/total_females*100;

# print(rate_males);
# print(rate_females);

# # Q27 Find loan approval rate by Education.

# tot_grads = df['Education'].value_counts().loc['Graduate'];
# tot_non_grads = df['Education'].value_counts().loc['Not Graduate'];
# approved_grads_loan = len(df.loc[(df['Loan_Status']=='Y')&(df['Education']=='Graduate')]);
# approved_nongrads_loan = len(df.loc[(df['Loan_Status']=='Y')&(df['Education']=='Not Graduate')]);

# grad = approved_grads_loan/tot_grads*100;
# print(grad);
# n_grad = approved_nongrads_loan/tot_non_grads*100;
# print(n_grad);

# # Q28 Find loan approval rate by Property_Area.

# Q30 Which category has highest loan approval? Urban Rural Semiurban
prop = df['Property_Area'].unique().tolist();
count = dict();
for pr in prop:
    count[pr] = len(df[(df['Property_Area'] == pr)&(df['Loan_Status']=='Y')]);
print(count);
max_loan = 0;
new = "";
for item in count:
    if count[item] > max_loan:
        max_loan = count[item];
        new = item;
print("item", max_loan);
# Out:
# {'Urban': 133, 'Rural': 110, 'Semiurban': 179}
# item 179
